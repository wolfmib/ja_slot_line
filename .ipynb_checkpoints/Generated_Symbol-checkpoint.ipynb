# %%
# V2 Main
import random

list_weight= {
    "H1": 10,
    "H2": 10,
    "H3": 10,
    "H4": 10,
    "H5": 10,
    "L1": 13,
    "L2": 13,
    "L3": 13,
    "L4": 13,
    "L5": 13,
    "L6": 18,
    "S1": 4,
    "W1": 4
}





list_symbol = ["H1","H2","H3","H4","H5","L1","L2","L3","L4","L5","L6","W1","S1"]
#list_symbol = ["SA","SB","SC","SD","SE","K","Q","J","W"]

generated_list = []
for any_symbol in list_symbol:
    for _ in range(list_weight[any_symbol]):
        generated_list.append(any_symbol)
        

random.shuffle(generated_list)
random.shuffle(generated_list)
random.shuffle(generated_list)
random.shuffle(generated_list)
random.shuffle(generated_list)
random.shuffle(generated_list)
random.shuffle(generated_list)
random.shuffle(generated_list)

print("😇: Main Game Your Size is  %d"%len(generated_list))
input()


for symbol in generated_list:
    print(symbol)
# Out:
# 😇: Main Game Your Size is  137
#
# H1
# L5
# W1
# L3
# L5
# L3
# L4
# L2
# H1
# L3
# L1
# H1
# L3
# H2
# H1
# H3
# H3
# H4
# L2
# H5
# H3
# L5
# W1
# W1
# S1
# H5
# S1
# W1
# L3
# W1
# H2
# L2
# H5
# W1
# H4
# L5
# W1
# L1
# L5
# L4
# H2
# H5
# H4
# H2
# L4
# L2
# H1
# H4
# H3
# L1
# H2
# L1
# W1
# L2
# W1
# L3
# H4
# L1
# H1
# L5
# H5
# L5
# H4
# L2
# L3
# L5
# L2
# H3
# L1
# L3
# L5
# L4
# L2
# L3
# H3
# L2
# L5
# L2
# W1
# L3
# L4
# L5
# H1
# H2
# L3
# H2
# L1
# H4
# S1
# L1
# L1
# L4
# L4
# L4
# L3
# W1
# H4
# L3
# H3
# L4
# L5
# W1
# L5
# H3
# L1
# L4
# H5
# H5
# H3
# H1
# L1
# L2
# W1
# H5
# L4
# L2
# H3
# L2
# W1
# L1
# W1
# H2
# H1
# L4
# H2
# W1
# H5
# H5
# W1
# H1
# L1
# H4
# H4
# L4
# H2
# S1
# W1
